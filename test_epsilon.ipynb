# %%
import numpy as np
import gym
import random
from lava_grid import ZigZag6x10
from tqdm import tqdm
import math
from agent_lava_v2 import agent
import matplotlib.pyplot as plt

# %%
# default setting
max_steps = 100
stochasticity = 0 # probability of the selected action failing and instead executing any of the remaining 3
no_render = True

env = ZigZag6x10(max_steps=max_steps, act_fail_prob=stochasticity, goal=(5, 9), numpy_state=False)
s = env.reset()
done = False
cum_reward = 0.0

# %%
""" Your agent"""
my_agent = agent(epsilon=0.001)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 490.37it/s]

# %%
num_episode = 3000
record = my_agent.activate_learn(num_episode)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 484.34it/s]

# %%
for i, val in enumerate(record):
    if val == 0.8099999999999999:
        print(i)
        break
# Out:
# 134

# %%
first_sensed_point = []
for i in range(100):
    num_episode = 300
    record = my_agent.activate_learn(num_episode) 
    for i, val in enumerate(record):
        if val == 0.8099999999999999:
            print(i)
            first_sensed_point.append(i)
            break
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 278.04it/s]
# 129
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 268.58it/s]
# 127
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 282.48it/s]
# 126
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 277.01it/s]
# 142
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 272.46it/s]
# 139
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:01<00:00, 275.60it/s]
# 130
# ...

# %%
np.var(first_sensed_point)
# Out:
# 142.74989999999997

# %%
np.mean(first_sensed_point)
# Out:
# 129.99

# %% [markdown]
# # epsilon=0.000: 131.17/135.8211
# # epsilon=0.001: 129.99/142.75
# # epsilon=0.005: 131.2/122.36
# # epsilon=0.01  : 133.4/133.0

# %%
my_agent = agent(epsilon=0.01)

num_episode = 3000
record = my_agent.activate_learn(num_episode) 
for i, val in enumerate(record):
    if val == 0.8099999999999999:
        print(i)
        first_sensed_point.append(i)
        break
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:06<00:00, 484.80it/s]
# 128

# %%
from sklearn import metrics

metrics.auc([i for i in range(len(record))], record)
# Out:
# 2253.7549999999997

# %% [markdown]
# # epsilon=0.000: 2304.93
# # epsilon=0.001: 2303.185
# # epsilon=0.005: 2284.765
# # epsilon=0.01  : 2253.755

# %%
np.random.seed(6546336)
random.seed(688164)

# %%
my_agent = agent(epsilon=0)

num_episode = 3000
record = my_agent.activate_learn(num_episode) 
for i, val in enumerate(record):
    if val == 0.8099999999999999:
        print(i)
        break
# Out:
#  ... (more hidden) ...
#  ... (more hidden) ...
# 130

# %%
from sklearn import metrics

metrics.auc([i for i in range(len(record))], record)
# Out:
# 2310.8449999999993

# %% [markdown]
# # epsilon=0.000: 2311.905/2310.845
# # epsilon=0.001: 2310.765/2305.130
# # epsilon=0.005: 2298.610/2304.955
# # epsilon=0.01  : 2300.135/2297.165
